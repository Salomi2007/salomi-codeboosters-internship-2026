# %%
import pandas as pd
df=pd.read_csv("/content/sample_data/student_performance.csv")
df.head()
# Out:
#    student_id          name  age  gender        department  semester  \
# 0        1001  Aarav Sharma   19    Male  Computer Science         2
# 1        1002   Priya Patel   20  Female  Computer Science         2
# 2        1003   Rohit Verma   19    Male       Electronics         2
# 3        1004   Sneha Reddy   20  Female        Mechanical         2
# 4        1005    Arjun Nair   19    Male  Computer Science         2
#
#    math_score  science_score  english_score  programming_score  \
# 0          85             78             72                 91
# 1          76             82             88                 79
# 2          65             74             61                 55
# 3          70             80             75                 48
# 4          92             88             81                 95
#
#    attendance_percentage       city  admission_year
# 0                     92     Mumbai            2023
# 1                     87  Ahmedabad            2023
# ...

# %%
df
# Out:
#     student_id            name  age  gender        department  semester  \
# 0         1001    Aarav Sharma   19    Male  Computer Science         2
# 1         1002     Priya Patel   20  Female  Computer Science         2
# 2         1003     Rohit Verma   19    Male       Electronics         2
# 3         1004     Sneha Reddy   20  Female        Mechanical         2
# 4         1005      Arjun Nair   19    Male  Computer Science         2
# 5         1006     Meera Joshi   20  Female       Electronics         2
# 6         1007     Kiran Kumar   21    Male             Civil         2
# 7         1008     Divya Singh   19  Female  Computer Science         2
# 8         1009    Rahul Mishra   20    Male        Mechanical         2
# 9         1010      Ananya Das   19  Female  Computer Science         2
# 10        1011     Vikram Iyer   20    Male       Electronics         2
# 11        1012     Pooja Gupta   19  Female             Civil         2
# ...

# %%
print(df.shape)
print(df.head().shape)
print(df.tail().shape)
# Out:
# (30, 13)
# (5, 13)
# (5, 13)
# 30

# %%
print("no of student:",df.shape[0])
print("no of columns:",df.shape[1])
# Out:
# no of student: 30
# no of columns: 13

# %%
print("columns in the dataset:",df.columns.tolist())
# Out:
# ['student_id', 'name', 'age', 'gender', 'department', 'semester', 'math_score', 'science_score', 'english_score', 'programming_score', 'attendance_percentage', 'city', 'admission_year']

# %%
print(df.dtypes)
# Out:
# student_id                int64
# name                     object
# age                       int64
# gender                   object
# department               object
# semester                  int64
# math_score                int64
# science_score             int64
# english_score             int64
# programming_score         int64
# attendance_percentage     int64
# city                     object
# admission_year            int64
# dtype: object

# %%
print(df.describe())
# Out:
#         student_id        age  semester  math_score  science_score  \
# count    30.000000  30.000000      30.0   30.000000      30.000000
# mean   1015.500000  19.733333       2.0   76.066667      77.833333
# std       8.803408   0.739680       0.0   11.467896       8.554423
# min    1001.000000  19.000000       2.0   56.000000      61.000000
# 25%    1008.250000  19.000000       2.0   67.250000      71.250000
# 50%    1015.500000  20.000000       2.0   75.500000      78.000000
# 75%    1022.750000  20.000000       2.0   85.750000      83.750000
# max    1030.000000  21.000000       2.0   95.000000      93.000000
#
#        english_score  programming_score  attendance_percentage  admission_year
# count      30.000000          30.000000              30.000000            30.0
# mean       74.166667          67.600000              84.500000          2023.0
# std        10.003735          21.041175               9.379913             0.0
# ...

# %%
print(df.isnull.sum())
//if is null it will replace with the sum value

# %%
display(df.head())
print(df.isnull().sum())
# Out:
# student_id               0
# name                     0
# age                      0
# gender                   0
# department               0
# semester                 0
# math_score               5
# science_score            0
# english_score            0
# programming_score        0
# attendance_percentage    0
# city                     0
# admission_year           0
# dtype: int64

# %%
print(df['department'].unique())
print(df['department'].value_counts())
# Out:
# ['Computer Science' 'Electronics' 'Mechanical' 'Civil']
# department
# Computer Science    13
# Electronics          6
# Mechanical           6
# Civil                5
# Name: count, dtype: int64

# %%
print(df['gender'].value_counts())
# Out:
# gender
# Male      15
# Female    15
# Name: count, dtype: int64

# %%
print(df['city'].unique())
print(df['city'].value_counts())
# Out:
# ['Mumbai' 'Ahmedabad' 'Delhi' 'Hyderabad' 'Kochi' 'Pune' 'Bangalore'
#  'Lucknow' 'Varanasi' 'Kolkata' 'Chennai' 'Jaipur' 'Mysore' 'Thrissur'
#  'Bhopal' 'Agra' 'Patna' 'Nagpur' 'Dehradun' 'Chandigarh'
#  'Thiruvananthapuram' 'Surat' 'Allahabad' 'Kanpur' 'Indore']
# city
# Kochi                 2
# Lucknow               2
# Thiruvananthapuram    2
# Agra                  2
# Kolkata               2
# Hyderabad             1
# Mumbai                1
# Delhi                 1
# Ahmedabad             1
# Varanasi              1
# Bangalore             1
# Pune                  1
# Jaipur                1
# Mysore                1
# Thrissur              1
# Bhopal                1
# Chennai               1
# Patna                 1
# Nagpur                1
# Dehradun              1
# Chandigarh            1
# Surat                 1
# Allahabad             1
# Kanpur                1
# Indore                1
# Name: count, dtype: int64

# %%
cs_student=df[df['department']=='Computer Science']
print(len(cs_student))
print(cs_student[['name','programming_score']])
# Out:
# 13
#               name  programming_score
# 0     Aarav Sharma                 91
# 1      Priya Patel                 79
# 4       Arjun Nair                 95
# 7      Divya Singh                 93
# 9       Ananya Das                 97
# 12      Suresh Rao                 88
# 14     Ajay Tiwari                 76
# 17  Swati Kulkarni                 92
# 19    Nisha Kapoor                 83
# 21     Tanvi Mehta                 96
# 24       Amit Bose                 89
# 26   Gaurav Shukla                 87
# 29  Akanksha Yadav                 94

# %%
cm_students=df[(df['city']=='Chennai') | (df['city']=='Mumbai')]
print(len(cm_students))

print(cm_students[['name','city','programming_score']])
# Out:
# 2
#             name     city  programming_score
# 0   Aarav Sharma   Mumbai                 91
# 10   Vikram Iyer  Chennai                 72

# %%
high=df[df['attendance_percentage']<=75]
print(high[['name','attendance_percentage']])
# Out:
#              name  attendance_percentage
# 5     Meera Joshi                     72
# 8    Rahul Mishra                     68
# 14    Ajay Tiwari                     75
# 16   Manoj Pandey                     65
# 20  Harish Pillai                     74
# 22   Sanjay Dubey                     70
# 27  Sunita Pillai                     73

# %%
df['Total_score']=df['math_score']+df['science_score']+df['programming_score']+df['english_score']
top_student=df.loc[df['Total_score'].idxmax()]
print(top_student)
low_student=df.loc[df['Total_score'].idxmin()]
print(low_student)
# Out:
# student_id                           1010
# name                           Ananya Das
# age                                    19
# gender                             Female
# department               Computer Science
# semester                                2
# math_score                             95
# science_score                          89
# english_score                          90
# programming_score                      97
# attendance_percentage                  98
# city                              Kolkata
# admission_year                       2023
# Total_score                           371
# Name: 9, dtype: object
# student_id                       1017
# name                     Manoj Pandey
# age                                21
# gender                           Male
# department                      Civil
# semester                            2
# math_score                         56
# science_score                      61
# ...
